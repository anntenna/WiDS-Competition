# %%
import pandas as pd
from pandas import DataFrame, Series

# %%
train = pd.read_csv('train.csv')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (12,49,51,56,91,126,145,163,165,166,167,168,169,171,173,174,176,177,242,244,246,248,252,255,274,290,291,292,294,295,296,332,344,366,374,376,397,414,440,491,620,634,639,642,643,645,710,713,760,769,810,829,929,954,979,1001,1002,1003,1004,1005,1024,1037,1041,1043,1062,1086,1099,1100,1121,1129,1136,1152,1153,1166,1168,1182,1193,1204,1205,1207,1208,1216,1226,1228,1230,1232,1234) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
train.head()
# Out:
#    train_id  AA3  AA4  AA5  AA6     AA7  AA14  AA15   DG1  is_female  \
# 0         0    3   32  3.0  NaN  323011  3854   481  1975          1
# 1         1    2   26  NaN  8.0  268131  2441   344  1981          1
# 2         2    1   16  NaN  7.0  167581   754   143  1995          1
# 3         3    4   44  5.0  NaN  445071  5705   604  1980          1
# 4         4    4   43  NaN  6.0  436161  5645   592  1958          1
#
#       ...       GN1  GN1_OTHERS GN2  GN2_OTHERS  GN3  GN3_OTHERS  GN4  \
# 0     ...      99.0         NaN  99         NaN   99         NaN   99
# 1     ...       NaN         NaN   1         NaN    2         NaN    2
# 2     ...       1.0         NaN   2         NaN    2         NaN    2
# 3     ...       NaN         NaN   2         NaN    2         NaN   99
# 4     ...       NaN         NaN   1         NaN    1         NaN    1
#
#    GN4_OTHERS  GN5  GN5_OTHERS
# 0         NaN   99         NaN
# 1         NaN    2         NaN
# 2         NaN    2         NaN
# ...

# %%
len(train)
# Out:
# 18255

# %%
Y = train.is_female

# %%
X = train[['DG3','DG4','DG6','DL0','DL1','DL26_5']]

# %%
X['Y'] = Y
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
X.head()
# Out:
#    DG3  DG4  DG6  DL0  DL1  DL26_5  Y
# 0    3    5    2    1    1       2  1
# 1    8    5    2    2    7       2  1
# 2    3    2    7    2    7       2  1
# 3    3    5    2    2    7       2  1
# 4    3    6    2    2    7       2  1

# %%
X.corr()
# Out:
#              DG3       DG4       DG6       DL0       DL1    DL26_5         Y
# DG3     1.000000  0.473673  0.479761 -0.025781  0.226241 -0.000357 -0.008646
# DG4     0.473673  1.000000  0.477623 -0.047409  0.237301  0.015914 -0.099952
# DG6     0.479761  0.477623  1.000000  0.046702  0.261275  0.013175 -0.014939
# DL0    -0.025781 -0.047409  0.046702  1.000000  0.011715  0.019305  0.625686
# DL1     0.226241  0.237301  0.261275  0.011715  1.000000 -0.007472  0.010338
# DL26_5 -0.000357  0.015914  0.013175  0.019305 -0.007472  1.000000 -0.025861
# Y      -0.008646 -0.099952 -0.014939  0.625686  0.010338 -0.025861  1.000000

# %%
train.corr()
# Out:
#                train_id       AA3       AA4       AA5       AA6       AA7  \
# train_id       1.000000 -0.009594 -0.008471  0.018879  0.000560 -0.008425
# AA3           -0.009594  1.000000  0.925447 -0.017953 -0.125486  0.924611
# AA4           -0.008471  0.925447  1.000000  0.016534 -0.103761  0.999793
# AA5            0.018879 -0.017953  0.016534  1.000000       NaN  0.029435
# AA6            0.000560 -0.125486 -0.103761       NaN  1.000000 -0.095861
# AA7           -0.008425  0.924611  0.999793  0.029435 -0.095861  1.000000
# AA14          -0.008490  0.117725  0.084883 -0.577408 -0.102801  0.074603
# AA15          -0.008434  0.958523  0.889837 -0.018612 -0.097144  0.889307
# DG1            0.002050 -0.070281 -0.068858 -0.011880  0.013301 -0.069531
# is_female      0.005130 -0.008179 -0.028591  0.012327 -0.014280 -0.028565
# DG3           -0.003614  0.018889  0.031169  0.000631  0.028437  0.031779
# DG3A          -0.000531  0.015543  0.015987  0.028956  0.031029  0.016046
# ...

# %%
corr = _

# %%
corr_col = corr['is_female']
corr_col[abs(corr_col) > 0.1]
# Out:
# is_female    1.000000
# DG5_2        0.168942
# DG5_4        0.267392
# DL0          0.625686
# DL4_5       -0.174775
# DL4_6        0.163906
# DL5         -0.104271
# DL7          0.256214
# DL13         0.152534
# G2P1_11     -0.265145
# G2P2_3      -0.237334
# G2P2_4       0.111075
# G2P2_5       0.118345
# G2P2_6       0.102364
# G2P2_9      -0.107811
# G2P2_12      0.146858
# G2P2_14     -0.224564
# G2P2_15     -0.577350
# G2P2_16      0.207445
# G2P2_96      0.126666
# G2P3_2      -0.329932
# G2P3_3       0.381147
# G2P3_5       0.349705
# G2P3_12     -0.117177
# G2P3_14      0.913500
# G2P3_15      0.192450
# G2P3_16     -0.385438
# G2P4_2       0.115385
# G2P4_4       0.273370
# G2P4_10      0.158696
#                ...
# IFI20_6     -0.117992
# IFI20_9      0.167818
# FL13         0.121179
# FL16         0.102487
# FL17         0.104799
# FB16A_2     -0.235293
# FB16A_4      0.523810
# FB16A_5     -0.218218
# FB16A_6     -0.109066
# FB16A_96     0.554700
# ...

# %%
imp_corr = _

# %%
from numpy import NaN
train.replace(99, NaN, inplace=True)

# %%
imp_corr_star = []
for x in imp_corr.index:
    non_null = train[x].value_counts().sum()
    if (non_null > 18000) and len(train[x].value_counts()) <= 2:
        imp_corr_star.append(x)

# %%
X_small = train[imp_corr_star]

# %%
X_small.head()
# Out:
#    is_female  DG5_2  DG5_4  DL0  DL4_5  DL4_6  MT2  MT10  MM1  IFI1_3  IFI3_3
# 0          1      2      2    1      2      2    2     2    2       2       2
# 1          1      2      2    2      2      2    2     2    2       2       2
# 2          1      2      2    2      1      2    2     2    2       2       2
# 3          1      2      2    2      2      2    1     1    2       2       2
# 4          1      2      2    2      2      2    2     2    2       2       2

# %%
X_small_clean = X_small.dropna()

# %%
X_final = X_small.loc[:, X_small.columns != 'is_female']
Y = X_small['is_female']

# %%
col_list = X_final.columns.values

# %%
col_list
# Out:
# array(['DG5_2', 'DG5_4', 'DL0', 'DL4_5', 'DL4_6', 'MT2', 'MT10', 'MM1',
#        'IFI1_3', 'IFI3_3'], dtype=object)

# %%
X_final.head()
# Out:
#    DG5_2  DG5_4  DL0  DL4_5  DL4_6  MT2  MT10  MM1  IFI1_3  IFI3_3
# 0      2      2    1      2      2    2     2    2       2       2
# 1      2      2    2      2      2    2     2    2       2       2
# 2      2      2    2      1      2    2     2    2       2       2
# 3      2      2    2      2      2    1     1    2       2       2
# 4      2      2    2      2      2    2     2    2       2       2

# %%
from sklearn.linear_model import SGDClassifier

# %%
clf = SGDClassifier(loss="modified_huber", penalty="l2", alpha=0.01)
clf.fit(X_final, Y)
# Out:
# SGDClassifier(alpha=0.01, average=False, class_weight=None, epsilon=0.1,
#        eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='modified_huber', n_iter=5, n_jobs=1,
#        penalty='l2', power_t=0.5, random_state=None, shuffle=True,
#        verbose=0, warm_start=False)

# %%
test = pd.read_csv('test.csv')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (11,13,48,50,55,90,125,144,162,163,164,166,168,169,170,171,172,174,176,241,243,245,247,251,254,273,289,291,292,293,295,296,312,313,314,331,343,365,373,375,396,413,439,490,619,623,630,633,638,642,644,669,712,759,768,788,809,828,928,953,978,1000,1001,1002,1003,1004,1023,1036,1040,1042,1063,1085,1098,1099,1120,1128,1135,1151,1152,1165,1167,1181,1192,1204,1205,1206,1207,1215,1225,1227,1229,1231,1233) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
X_test = test[X_final.columns.values]

# %%
clf.predict_proba(X_test)
# Out:
# array([[ 0.20132101,  0.79867899],
#        [ 0.63877283,  0.36122717],
#        [ 0.17774679,  0.82225321],
#        ...,
#        [ 1.        ,  0.        ],
#        [ 0.10074161,  0.89925839],
#        [ 0.10074161,  0.89925839]])

# %%
clf.score(X_final, Y)
# Out:
# 0.82114489181046291

# %%
X_test.head()
# Out:
#    DG5_2  DG5_4  DL0  DL4_5  DL4_6  MT2  MT10  MM1  IFI1_3  IFI3_3
# 0      2      2    2      2      1    2     2    2       1       1
# 1      1      2    2      2      2    1     1    1       2       2
# 2      1      2    2      2      2    2     2    2       2       2
# 3      2      2    2      1      2    2     1    2       2       2
# 4      1      1    2      2      2    2     2    2       2       2

# %%
probs = [x[1] for x in clf.predict_proba(X_test)]
test['is_female'] = probs

# %%
results = test[['test_id','is_female']]

# %%
results.set_index('test_id', inplace=True)

# %%
results.to_csv('results.csv')

# %%
from sklearn.pipeline import Pipeline
from sklearn import base

class ColumnSelectTransformer(base.BaseEstimator, base.TransformerMixin):
    
    def __init__(self, col_names):
        self.col_names = col_names  
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        print(X)
        data = [row[col] for col in self.col_names for row in X]
        return data

# %%
sdg_estimator = Pipeline([
    #('columnSelector', ColumnSelectTransformer(col_list)),
    ('regressor', SGDClassifier())
    
])

# %%
from sklearn.model_selection import GridSearchCV

params_dict = {
    'regressor__alpha':[0.0001, 0.01, 0.1, 1, 10],
    'regressor__loss':['log','modified_huber'],
    'regressor__penalty':['l1','l2','elasticnet']
}
grid_est = GridSearchCV(estimator=sdg_estimator, param_grid=params_dict)
grid_est.fit(X_final, Y)
# Out:
# GridSearchCV(cv=None, error_score='raise',
#        estimator=Pipeline(steps=[('regressor', SGDClassifier(alpha=0.0001, average=False, class_weight=None, epsilon=0.1,
#        eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', n_iter=5, n_jobs=1,
#        penalty='l2', power_t=0.5, random_state=None, shuffle=True,
#        verbose=0, warm_start=False))]),
#        fit_params={}, iid=True, n_jobs=1,
#        param_grid={'regressor__alpha': [0.0001, 0.01, 0.1, 1, 10], 'regressor__loss': ['log', 'modified_huber'], 'regressor__penalty': ['l1', 'l2', 'elasticnet']},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=None, verbose=0)

# %%
grid_est.best_estimator_.score(X_final, Y)
# Out:
# 0.82076143522322653

# %%
grid_est.best_params_
# Out:
# {'regressor__alpha': 0.01,
#  'regressor__loss': 'modified_huber',
#  'regressor__penalty': 'l2'}
